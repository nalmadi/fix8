# %%
import pandas as pd

hit_test_data = pd.read_csv('C:\\Users\\nsser\\OneDrive\\Desktop\\Research\\Fix8-repo\\experiment material\\starter_examples\\trial_2_hit_test.csv')
hit_test_data.head()
# Out:
#                                            file_name       fix_x  fix_y  \
# 0  C:/Users/nsser/OneDrive/Desktop/Research/Fix8-...  168.166667  166.0
# 1  C:/Users/nsser/OneDrive/Desktop/Research/Fix8-...  308.500000  166.0
# 2  C:/Users/nsser/OneDrive/Desktop/Research/Fix8-...  399.166667  178.0
# 3  C:/Users/nsser/OneDrive/Desktop/Research/Fix8-...  464.500000  173.0
# 4  C:/Users/nsser/OneDrive/Desktop/Research/Fix8-...  548.500000  178.0
#
#    duration  aoi_x  aoi_y  aoi_width  aoi_height  line  part         image
# 0     300.0  137.5    147        119          44     1     1  stimulus.png
# 1     250.0  262.5    147        112          44     1     2  stimulus.png
# 2     200.0  382.5    147         65          44     1     3  stimulus.png
# 3     150.0  453.5    147         57          44     1     4  stimulus.png
# 4     150.0  514.5    147         72          44     1     5  stimulus.png

# %%
# print type of column part
print(hit_test_data['part'].dtype)
# Out:
# int64

# %%
hit_test_data[hit_test_data["part"] == 1]
# Out:
#                                             file_name       fix_x  fix_y  \
# 0   C:/Users/nsser/OneDrive/Desktop/Research/Fix8-...  168.166667  166.0
# 9   C:/Users/nsser/OneDrive/Desktop/Research/Fix8-...  180.166667  223.0
# 16  C:/Users/nsser/OneDrive/Desktop/Research/Fix8-...  146.166667  262.0
# 35  C:/Users/nsser/OneDrive/Desktop/Research/Fix8-...  174.833333  368.0
# 56  C:/Users/nsser/OneDrive/Desktop/Research/Fix8-...  181.833333  409.0
#
#     duration  aoi_x  aoi_y  aoi_width  aoi_height  line  part         image
# 0      300.0  137.5    147        119          44     1     1  stimulus.png
# 9      350.0  138.5    197        140          44     2     1  stimulus.png
# 16     150.0  137.5    246         52          44     3     1  stimulus.png
# 35     200.0  137.5    346         82          44     5     1  stimulus.png
# 56     400.0  137.5    395        157          44     6     1  stimulus.png
